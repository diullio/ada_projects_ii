# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("EDA_Industrializados_202110.csv", sep=";", encoding='latin1')

# %%
df.head(5)
# Out:
#    ANO_VENDA  MES_VENDA UF_VENDA   MUNICIPIO_VENDA PRINCIPIO_ATIVO  \
# 0       2021         10       SP  IGARAÇU DO TIETÊ      CELECOXIBE
# 1       2021         10       SP  IGARAÇU DO TIETÊ      CELECOXIBE
# 2       2021         10       SP  IGARAÇU DO TIETÊ      CELECOXIBE
# 3       2021         10       SP  IGARAÇU DO TIETÊ      CELECOXIBE
# 4       2021         10       SP  IGARAÇU DO TIETÊ      CELECOXIBE
#
#                               DESCRICAO_APRESENTACAO  QTD_VENDIDA  \
# 0  200 MG CAP DURA CT BL AL PLAS PVC/PCTFE TRANS ...           14
# 1  200 MG CAP DURA CT BL AL PLAS PVC/PCTFE TRANS ...            1
# 2  200 MG CAP DURA CT BL AL PLAS PVC/PCTFE TRANS ...            3
# 3  200 MG CAP DURA CT BL AL PLAS PVC/PCTFE TRANS ...            1
# 4           200 MG CAP DURA CT BL AL PLAS TRANS X 10            3
#
#   UNIDADE_MEDIDA CONSELHO_PRESCRITOR UF_CONSELHO_PRESCRITOR  TIPO_RECEITUARIO  \
# 0          CAIXA                 CRM                     SP               1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5989708 entries, 0 to 5989707
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   ANO_VENDA               int64
#  1   MES_VENDA               int64
#  2   UF_VENDA                object
#  3   MUNICIPIO_VENDA         object
#  4   PRINCIPIO_ATIVO         object
#  5   DESCRICAO_APRESENTACAO  object
#  6   QTD_VENDIDA             int64
#  7   UNIDADE_MEDIDA          object
#  8   CONSELHO_PRESCRITOR     object
#  9   UF_CONSELHO_PRESCRITOR  object
#  10  TIPO_RECEITUARIO        float64
#  11  CID10                   object
#  12  SEXO                    float64
#  13  IDADE                   float64
#  14  UNIDADE_IDADE           float64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 685.5+ MB

# %%
x = df.groupby([df["PRINCIPIO_ATIVO"], df["UF_VENDA"]]).sum()
x
# Out:
#                                                              ANO_VENDA  \
# PRINCIPIO_ATIVO                                    UF_VENDA
# 17-VALERATO DE BETAMETASONA + CLIOQUINOL + SULF... BA             2021
#                                                    MA             2021
#                                                    MG             6063
#                                                    SP             8084
#                                                    TO             2021
# ...                                                                ...
# ÁCIDO VALPRÓICO + VALPROATO DE SÓDIO               SC          1050920
#                                                    SE           161680
#                                                    SP          2568691
#                                                    TO           270814
# ÓXIDO DE ZINCO                                     RJ             2021
#
# ...

# %%
x.loc["17-VALERATO DE BETAMETASONA + CLIOQUINOL + SULFATO DE GENTAMICINA + TOLNAFTATO"]
# Out:
#           ANO_VENDA  MES_VENDA  QTD_VENDIDA  TIPO_RECEITUARIO  SEXO  IDADE  \
# UF_VENDA
# BA             2021         10            2               5.0   1.0   31.0
# MA             2021         10            1               5.0   2.0   30.0
# MG             6063         30            7              11.0   3.0   43.0
# SP             8084         40            5              20.0   5.0  135.0
# TO             2021         10            1               5.0   1.0   26.0
#
#           UNIDADE_IDADE
# UF_VENDA
# BA                  1.0
# MA                  1.0
# MG                  3.0
# SP                  4.0
# TO                  1.0

# %%
x.pop("UNIDADE_IDADE")
# Out:
# PRINCIPIO_ATIVO                                                                 UF_VENDA
# 17-VALERATO DE BETAMETASONA + CLIOQUINOL + SULFATO DE GENTAMICINA + TOLNAFTATO  BA            1
#                                                                                 MA            1
#                                                                                 MG            3
#                                                                                 SP            4
#                                                                                 TO            1
#                                                                                            ...
# ÁCIDO VALPRÓICO + VALPROATO DE SÓDIO                                            SC           20
#                                                                                 SE            2
#                                                                                 SP          119
# ...

# %%
x
# Out:
#                                                              ANO_VENDA  \
# PRINCIPIO_ATIVO                                    UF_VENDA
# 17-VALERATO DE BETAMETASONA + CLIOQUINOL + SULF... BA             2021
#                                                    MA             2021
#                                                    MG             6063
#                                                    SP             8084
#                                                    TO             2021
# ...                                                                ...
# ÁCIDO VALPRÓICO + VALPROATO DE SÓDIO               SC          1050920
#                                                    SE           161680
#                                                    SP          2568691
#                                                    TO           270814
# ÓXIDO DE ZINCO                                     RJ             2021
#
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8319 entries, ('17-VALERATO DE BETAMETASONA + CLIOQUINOL + SULFATO DE GENTAMICINA + TOLNAFTATO', 'BA') to ('ÓXIDO DE ZINCO', 'RJ')
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ANO_VENDA         8319 non-null   int64
#  1   MES_VENDA         8319 non-null   int64
#  2   QTD_VENDIDA       8319 non-null   int64
#  3   TIPO_RECEITUARIO  8319 non-null   float64
#  4   SEXO              8319 non-null   float64
#  5   IDADE             8319 non-null   float64
#  6   UNIDADE_IDADE     8319 non-null   float64
# dtypes: float64(4), int64(3)
# memory usage: 485.9+ KB
